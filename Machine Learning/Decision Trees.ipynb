# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from subprocess import check_call
import matplotlib.pyplot as plt

# %% [markdown]
# # Classification using Decision Trees

# %%
#Creating conditions for the classification task
iris = load_iris()

X = iris.data[:, 2:] #Taking petal length and width as features
y = iris.target

# %%
#Training Decision Tree Classifier for the dataset
tree_classifier = DecisionTreeClassifier(max_depth=2)
tree_classifier.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
#Visualizing the trained Decision Tree
plot_tree(
    tree_classifier,
    feature_names = iris.feature_names[2:],
    class_names = iris.target_names,
    rounded = True,
    filled = True
)
# Out:
# [Text(133.92000000000002, 181.2, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(200.88000000000002, 108.72, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica')]

# %%
#Estimating class probabilites for the Classifier
tree_classifier.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
#Predicting the class
tree_classifier.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # Regression using Decesion Trees

# %%
#Training Decision Tree Regressor for the data set
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
#Visualizing tree structure for the regressor
plot_tree(tree_reg)
# Out:
# [Text(133.92000000000002, 181.2, 'X[1] <= 0.8\nmse = 0.667\nsamples = 150\nvalue = 1.0'),
#  Text(66.96000000000001, 108.72, 'mse = 0.0\nsamples = 50\nvalue = 0.0'),
#  Text(200.88000000000002, 108.72, 'X[1] <= 1.75\nmse = 0.25\nsamples = 100\nvalue = 1.5'),
#  Text(133.92000000000002, 36.23999999999998, 'mse = 0.084\nsamples = 54\nvalue = 1.093'),
#  Text(267.84000000000003, 36.23999999999998, 'mse = 0.021\nsamples = 46\nvalue = 1.978')]
